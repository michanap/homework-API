# %%
import os
import plaid
import requests
import datetime
import json
import pandas as pd
# %matplotlib inline

# %%
def pretty_print_response(response):
  print(json.dumps(response, indent=4, sort_keys=True))

# %%
PLAID_CLIENT_ID = os.getenv('PLAID_CLIENT_ID')
PLAID_SECRET = os.getenv('PLAID_SECRET')
PLAID_PUBLIC_KEY = os.getenv('PLAID_PUBLIC_KEY')
PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')

# %% [markdown]
# # Plaid Access Token
#
# In this section, you will use the plaid-python api to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
# 1. Create a client to connect to paid
# 2. Use the client to generate a public token and request the following items:
# ['transactions', 'income', 'assets']
# 3. Exchange the public token for an access token
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
INSTITUTION_ID = "ins_109508"

# %%
# YOUR CODE HERE
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SECRET, public_key=PLAID_PUBLIC_KEY, environment='sandbox')
client.Institutions.get(3)
# Out:
# {'institutions': [{'country_codes': ['US'],
#    'credentials': [{'label': 'Username', 'name': 'username', 'type': 'text'},
#     {'label': 'Password', 'name': 'password', 'type': 'password'}],
#    'has_mfa': False,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_25',
#    'mfa': [],
#    'mfa_code_type': 'numeric',
#    'name': 'Ally Bank',
#    'products': ['assets',
#     'auth',
#     'balance',
#     'transactions',
#     'income',
#     'identity'],
#    'routing_numbers': ['124003116']},
#   {'country_codes': ['US'],
#    'credentials': [{'label': 'Login ID', 'name': 'username', 'type': 'text'},
#     {'label': 'Password', 'name': 'password', 'type': 'password'}],
#    'has_mfa': True,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_113968',
#    'mfa': ['questions'],
#    'mfa_code_type': 'numeric',
#    'name': 'Amegy Bank of Texas - Personal Banking',
#    'products': ['assets', 'auth', 'balance', 'transactions', 'income'],
#    'routing_numbers': ['113011258']},
#   {'country_codes': ['US'],
#    'credentials': [{'label': 'User ID', 'name': 'username', 'type': 'text'},
#     {'label': 'Password', 'name': 'password', 'type': 'password'}],
#    'has_mfa': False,
#    'input_spec': 'fixed',
#    'institution_id': 'ins_10',
#    'mfa': [],
#    'mfa_code_type': 'numeric',
#    'name': 'American Express',
#    'products': ['assets', 'balance', 'transactions', 'income', 'liabilities'],
#    'routing_numbers': []}],
#  'request_id': 'dxCv4BeylDwRDG6',
#  'total': 10431}

# %% [markdown]
# ### 2. Generate a public token

# %%
# YOUR CODE HERE
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# YOUR CODE HERE
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])
access_token = exchange_response['access_token']
type(access_token)
# Out:
# str

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# YOUR CODE HERE
client.Accounts.get(access_token)
# Out:
# {'accounts': [{'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': '4on3Gl9gEZIEj87n181Nhna1lE6deefdo1PMP',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': 'N58egWo34Pi5ZoVl9o9Ph69KJkbP33fW3DwKz',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '2222',
#    'name': 'Plaid CD',
#    'official_name': 'Plaid Bronze Standard 0.2% Interest CD',
#    'subtype': 'cd',
#    'type': 'depository'},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'balances': {'available': None,
#     'current': 410,
#     'iso_currency_code': 'USD',
#     'limit': 2000,
#     'unofficial_currency_code': None},
#    'mask': '3333',
#    'name': 'Plaid Credit Card',
#    'official_name': 'Plaid Diamond 12.5% APR Interest Credit Card',
#    'subtype': 'credit card',
#    'type': 'credit'},
#   {'account_id': 'jlLePojKD7sABbNpQbQDU3pB4GvQ99C1EXeAo',
#    'balances': {'available': 43200,
#     'current': 43200,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '4444',
#    'name': 'Plaid Money Market',
#    'official_name': 'Plaid Platinum Standard 1.85% Interest Money Market',
#    'subtype': 'money market',
#    'type': 'depository'},
#   {'account_id': '7ERJlr6WGXiEm8R9K8K7hvDoZadjWWfgZ9qpN',
#    'balances': {'available': None,
#     'current': 320.76,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '5555',
#    'name': 'Plaid IRA',
#    'official_name': None,
#    'subtype': 'ira',
#    'type': 'investment'},
#   {'account_id': 'e5Mq1Zd89wijkoAvNoNdFjBERrxzmmcLgjGkL',
#    'balances': {'available': None,
#     'current': 23631.9805,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '6666',
#    'name': 'Plaid 401k',
#    'official_name': None,
#    'subtype': '401k',
#    'type': 'investment'},
#   {'account_id': 'Q5pemnEajZi58nJ9BnBAhbGKp3XZVVip18Vew',
#    'balances': {'available': None,
#     'current': 65262,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '7777',
#    'name': 'Plaid Student Loan',
#    'official_name': None,
#    'subtype': 'student',
#    'type': 'loan'}],
#  'item': {'available_products': ['auth',
#    'balance',
#    'credit_details',
#    'identity',
#    'investments',
#    'liabilities'],
#   'billed_products': ['assets', 'income', 'transactions'],
#   'error': None,
#   'institution_id': 'ins_109508',
#   'item_id': 'qxJm9nLazAsnZNjagNgxFqGAJxAoxvTdak5Az',
#   'webhook': ''},
#  'request_id': 'hhfbqjo57eS7gKL'}

# %% [markdown]
# ---

# %% [markdown]
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
# 2. Print the categories for each transaction type
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# YOUR CODE HERE
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())
transactions_response = client.Transactions.get(access_token, start_date, end_date)
transactions_response
# Out:
# {'accounts': [{'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': '4on3Gl9gEZIEj87n181Nhna1lE6deefdo1PMP',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': 'N58egWo34Pi5ZoVl9o9Ph69KJkbP33fW3DwKz',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '2222',
#    'name': 'Plaid CD',
#    'official_name': 'Plaid Bronze Standard 0.2% Interest CD',
#    'subtype': 'cd',
#    'type': 'depository'},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'balances': {'available': None,
#     'current': 410,
#     'iso_currency_code': 'USD',
#     'limit': 2000,
#     'unofficial_currency_code': None},
#    'mask': '3333',
#    'name': 'Plaid Credit Card',
#    'official_name': 'Plaid Diamond 12.5% APR Interest Credit Card',
#    'subtype': 'credit card',
#    'type': 'credit'},
#   {'account_id': 'jlLePojKD7sABbNpQbQDU3pB4GvQ99C1EXeAo',
#    'balances': {'available': 43200,
#     'current': 43200,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '4444',
#    'name': 'Plaid Money Market',
#    'official_name': 'Plaid Platinum Standard 1.85% Interest Money Market',
#    'subtype': 'money market',
#    'type': 'depository'},
#   {'account_id': '7ERJlr6WGXiEm8R9K8K7hvDoZadjWWfgZ9qpN',
#    'balances': {'available': None,
#     'current': 320.76,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '5555',
#    'name': 'Plaid IRA',
#    'official_name': None,
#    'subtype': 'ira',
#    'type': 'investment'},
#   {'account_id': 'e5Mq1Zd89wijkoAvNoNdFjBERrxzmmcLgjGkL',
#    'balances': {'available': None,
#     'current': 23631.9805,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '6666',
#    'name': 'Plaid 401k',
#    'official_name': None,
#    'subtype': '401k',
#    'type': 'investment'},
#   {'account_id': 'Q5pemnEajZi58nJ9BnBAhbGKp3XZVVip18Vew',
#    'balances': {'available': None,
#     'current': 65262,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '7777',
#    'name': 'Plaid Student Loan',
#    'official_name': None,
#    'subtype': 'student',
#    'type': 'loan'}],
#  'item': {'available_products': ['auth',
#    'balance',
#    'credit_details',
#    'identity',
#    'investments',
#    'liabilities'],
#   'billed_products': ['assets', 'income', 'transactions'],
#   'error': None,
#   'institution_id': 'ins_109508',
#   'item_id': 'qxJm9nLazAsnZNjagNgxFqGAJxAoxvTdak5Az',
#   'webhook': ''},
#  'request_id': 'KhR0CbVBpca01cu',
#  'total_transactions': 48,
#  'transactions': [{'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-09-28',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Tectra Inc',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'Z5Exe3vGoBiKwnX9lnlAIXMNMxwd8MFg1DbQz',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 2078.5,
#    'category': ['Payment'],
#    'category_id': '16000000',
#    'date': '2019-09-27',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'AUTOMATIC PAYMENT - THANK',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'L5pRo8LzdPi5ELwmxLxMh97D7Alap7TPWy9DB',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-09-27',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'KFC',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '116emnbDoWhqwQvJ5Q5XI14D4mRAe4h5PGmWD',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Shops', 'Sporting Goods'],
#    'category_id': '19046000',
#    'date': '2019-09-27',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Madison Bicycle Shop',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'M5g1okpBaPi5npZMVpVNhD363JQyg3f9R87nN',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': '4on3Gl9gEZIEj87n181Nhna1lE6deefdo1PMP',
#    'account_owner': None,
#    'amount': 25,
#    'category': ['Payment', 'Credit Card'],
#    'category_id': '16001000',
#    'date': '2019-09-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CREDIT CARD 3333 PAYMENT *//',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '7ERJlr6WGXiEm8R9K8K7hvDoDw3ajDugBK1v8',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 5.4,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-09-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 063015 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'd5Ml8QxAyZiWjvba4v4xHaxnxlzG5xcZnx6gq',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'jlLePojKD7sABbNpQbQDU3pB4GvQ99C1EXeAo',
#    'account_owner': None,
#    'amount': 5850,
#    'category': ['Transfer', 'Debit'],
#    'category_id': '21006000',
#    'date': '2019-09-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'ACH Electronic CreditGUSTO PAY 123456',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': 'ACH',
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'g5Mrk14LR7ieKwdPjwj4sEWlW9zGdWHg7QM3a',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'N58egWo34Pi5ZoVl9o9Ph69KJkbP33fW3DwKz',
#    'account_owner': None,
#    'amount': 1000,
#    'category': ['Transfer', 'Deposit'],
#    'category_id': '21007000',
#    'date': '2019-09-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CD DEPOSIT .INITIAL.',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'Q5pemnEajZi58nJ9BnBAhbGKGa63ZGFplWaya',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 78.5,
#    'category': ['Recreation', 'Gyms and Fitness Centers'],
#    'category_id': '17018000',
#    'date': '2019-09-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Touchstone Climbing',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'p3MJ9G1drAhzrR4WoRo3H9GQGrgydGTLQNKR8',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': -500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-09-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'a56E9jzLn7ivm5o3x5xzcbynyARdjyF7Kxedb',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 12,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-09-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': '3322'},
#    'name': "McDonald's",
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '4on3Gl9gEZIEj87n181Nhna1abVEdafdRw3D8',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 4.33,
#    'category': ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#    'category_id': '13005043',
#    'date': '2019-09-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Starbucks',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'N58egWo34Pi5ZoVl9o9Ph69K9MVkP9fWAq7er',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 89.4,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-09-14',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'SparkFun',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'P5kyoG8dP7i5vnX96n6MhVeqeBLv7ec7yrN37',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': '4on3Gl9gEZIEj87n181Nhna1lE6deefdo1PMP',
#    'account_owner': None,
#    'amount': -4.22,
#    'category': ['Transfer', 'Credit'],
#    'category_id': '21005000',
#    'date': '2019-09-13',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'INTRST PYMNT',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'e5Mq1Zd89wijkoAvNoNdFjBEBGVrzBCL3lV67',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-09-03',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'oB1R9AMkKysrKb46pbpBIJ343Mgjp3uRVnKLw',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 6.33,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-09-01',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 072515 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'jlLePojKD7sABbNpQbQDU3pBpMJGQpc1R8Gp6',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-08-29',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Tectra Inc',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'mkMebEQBlAfqlb4M1b1kI5EAgpDMoVsLEvalN',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 2078.5,
#    'category': ['Payment'],
#    'category_id': '16000000',
#    'date': '2019-08-28',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'AUTOMATIC PAYMENT - THANK',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'bJDag7B9byI4g1red1dBHD7jkEZN5VFVl4eJL',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-08-28',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'KFC',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'nzRXwWZ3qAUKqbQDLbLzIBbRLVjK6Dt6oy4Xe',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Shops', 'Sporting Goods'],
#    'category_id': '19046000',
#    'date': '2019-08-28',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Madison Bicycle Shop',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'G5nGo1eErdi5Ee8PnenQhV7e19a5Aqi1aedLp',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': '4on3Gl9gEZIEj87n181Nhna1lE6deefdo1PMP',
#    'account_owner': None,
#    'amount': 25,
#    'category': ['Payment', 'Credit Card'],
#    'category_id': '16001000',
#    'date': '2019-08-19',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CREDIT CARD 3333 PAYMENT *//',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'G5nGo1eErdi5Ee8PnenQhV7e19a5Aqi1aedB8',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 5.4,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-08-19',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 063015 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'W5Xozrme1ki5WdbaZdZAhDnorRAMGdFlRmVbw',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'jlLePojKD7sABbNpQbQDU3pB4GvQ99C1EXeAo',
#    'account_owner': None,
#    'amount': 5850,
#    'category': ['Transfer', 'Debit'],
#    'category_id': '21006000',
#    'date': '2019-08-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'ACH Electronic CreditGUSTO PAY 123456',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': 'ACH',
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '4on3Gl9gEZIEj87n181NhnajNQRBv3Fdo1PqX',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'N58egWo34Pi5ZoVl9o9Ph69KJkbP33fW3DwKz',
#    'account_owner': None,
#    'amount': 1000,
#    'category': ['Transfer', 'Deposit'],
#    'category_id': '21007000',
#    'date': '2019-08-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CD DEPOSIT .INITIAL.',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'x7Dd5zAZNKiPwm5pbmbLCQxlaL3J6jHn1Gbw4',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 78.5,
#    'category': ['Recreation', 'Gyms and Fitness Centers'],
#    'category_id': '17018000',
#    'date': '2019-08-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Touchstone Climbing',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'ARwlpjavDKIZeam3xax7h4rjGMwNWEc18Xmk8',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': -500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-08-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'E5VzvZjgq3i58jLmBjBNhVkGpXBxWwiXyKNBg',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 12,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-08-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': '3322'},
#    'name': "McDonald's",
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'g5Mrk14LR7ieKwdPjwj4sEWrJwo4nbigomJ6g',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 4.33,
#    'category': ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#    'category_id': '13005043',
#    'date': '2019-08-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Starbucks',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '8kJxqzl8nZfdAlM87l7GIlM1maJqnetwnlBXW',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 89.4,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-08-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'SparkFun',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'oB1R9AMkKysrKb46pbpBIJ3DAKdk6rFRjlmZX',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': '4on3Gl9gEZIEj87n181Nhna1lE6deefdo1PMP',
#    'account_owner': None,
#    'amount': -4.22,
#    'category': ['Transfer', 'Credit'],
#    'category_id': '21005000',
#    'date': '2019-08-14',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'INTRST PYMNT',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'ARwlpjavDKIZeam3xax7h4rjGMwNWEc18Xmjo',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-08-04',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'W5Xozrme1ki5WdbaZdZAhDnorRAMGdFlRmV5r',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 6.33,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-08-02',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 072515 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'p3MJ9G1drAhzrR4WoRo3H9G7kjZEVziLw1dv9',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-07-30',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Tectra Inc',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'E5VzvZjgq3i58jLmBjBNhVkGpXBxWwiXyKNMK',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 2078.5,
#    'category': ['Payment'],
#    'category_id': '16000000',
#    'date': '2019-07-29',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'AUTOMATIC PAYMENT - THANK',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '8kJxqzl8nZfdAlM87l7GIlM1maJqnetwnlBRy',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-07-29',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'KFC',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'g5Mrk14LR7ieKwdPjwj4sEWrJwo4nbigomJGx',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Shops', 'Sporting Goods'],
#    'category_id': '19046000',
#    'date': '2019-07-29',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Madison Bicycle Shop',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'oB1R9AMkKysrKb46pbpBIJ3DAKdk6rFRjlmPe',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': '4on3Gl9gEZIEj87n181Nhna1lE6deefdo1PMP',
#    'account_owner': None,
#    'amount': 25,
#    'category': ['Payment', 'Credit Card'],
#    'category_id': '16001000',
#    'date': '2019-07-20',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CREDIT CARD 3333 PAYMENT *//',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'W5Xozrme1ki5WdbaZdZAhDnorRAMGdFlRmV9w',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 5.4,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-07-20',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 063015 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'L5pRo8LzdPi5ELwmxLxMh97vJX8yKMiP7r5x4',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'jlLePojKD7sABbNpQbQDU3pB4GvQ99C1EXeAo',
#    'account_owner': None,
#    'amount': 5850,
#    'category': ['Transfer', 'Debit'],
#    'category_id': '21006000',
#    'date': '2019-07-19',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'ACH Electronic CreditGUSTO PAY 123456',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': 'ACH',
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'a56E9jzLn7ivm5o3x5xzcbyLX751DEu7NWMbg',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'N58egWo34Pi5ZoVl9o9Ph69KJkbP33fW3DwKz',
#    'account_owner': None,
#    'amount': 1000,
#    'category': ['Transfer', 'Deposit'],
#    'category_id': '21007000',
#    'date': '2019-07-19',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CD DEPOSIT .INITIAL.',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '3pnWdmyD8JhRB8nJ5854tdBWZr4zVKfqA1xJb',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 78.5,
#    'category': ['Recreation', 'Gyms and Fitness Centers'],
#    'category_id': '17018000',
#    'date': '2019-07-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Touchstone Climbing',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'p3MJ9G1drAhzrR4WoRo3H9G7kjZEVziLw1dqo',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': -500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-07-18',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': '116emnbDoWhqwQvJ5Q5XI14Ky8jdWGT5zJ1ka',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 12,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-07-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': '3322'},
#    'name': "McDonald's",
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'Z5Exe3vGoBiKwnX9lnlAIXMqD3LrzAcg3KBEp',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 4.33,
#    'category': ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#    'category_id': '13005043',
#    'date': '2019-07-17',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Starbucks',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'M5g1okpBaPi5npZMVpVNhD3nvLxKpRF9KMrWr',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 89.4,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2019-07-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'SparkFun',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'Q5pemnEajZi58nJ9BnBAhbGRk1ovxnup18Vgo',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': '4on3Gl9gEZIEj87n181Nhna1lE6deefdo1PMP',
#    'account_owner': None,
#    'amount': -4.22,
#    'category': ['Transfer', 'Credit'],
#    'category_id': '21005000',
#    'date': '2019-07-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'INTRST PYMNT',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'E5VzvZjgq3i58jLmBjBNhVkGpXBxWwiXyKNRg',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'P5kyoG8dP7i5vnX96n6MhVeqDv47ZZC71MRvb',
#    'account_owner': None,
#    'amount': 500,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2019-07-05',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'L5pRo8LzdPi5ELwmxLxMh97vJX8yKMiP7r5mK',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'a56E9jzLn7ivm5o3x5xzcbynqdQjzzi7NWM3w',
#    'account_owner': None,
#    'amount': 6.33,
#    'category': ['Travel', 'Car Service', 'Ride Share'],
#    'category_id': '22006001',
#    'date': '2019-07-03',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber 072515 SF**POOL**',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_id': 'e5Mq1Zd89wijkoAvNoNdFjBQ1P375atLgjGbd',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None}]}

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# YOUR CODE HERE
trans_categories = [trans["category"] for trans in transactions_response['transactions']]
trans_categories
# Out:
# [['Food and Drink', 'Restaurants'],
#  ['Payment'],
#  ['Food and Drink', 'Restaurants'],
#  ['Shops', 'Sporting Goods'],
#  ['Payment', 'Credit Card'],
#  ['Travel', 'Car Service', 'Ride Share'],
#  ['Transfer', 'Debit'],
#  ['Transfer', 'Deposit'],
#  ['Recreation', 'Gyms and Fitness Centers'],
#  ['Travel', 'Airlines and Aviation Services'],
#  ['Food and Drink', 'Restaurants'],
#  ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#  ['Food and Drink', 'Restaurants'],
#  ['Transfer', 'Credit'],
#  ['Travel', 'Airlines and Aviation Services'],
#  ['Travel', 'Car Service', 'Ride Share'],
#  ['Food and Drink', 'Restaurants'],
#  ['Payment'],
#  ['Food and Drink', 'Restaurants'],
#  ['Shops', 'Sporting Goods'],
#  ['Payment', 'Credit Card'],
#  ['Travel', 'Car Service', 'Ride Share'],
#  ['Transfer', 'Debit'],
#  ['Transfer', 'Deposit'],
#  ['Recreation', 'Gyms and Fitness Centers'],
#  ['Travel', 'Airlines and Aviation Services'],
#  ['Food and Drink', 'Restaurants'],
#  ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#  ['Food and Drink', 'Restaurants'],
#  ['Transfer', 'Credit'],
#  ['Travel', 'Airlines and Aviation Services'],
#  ['Travel', 'Car Service', 'Ride Share'],
#  ['Food and Drink', 'Restaurants'],
#  ['Payment'],
#  ['Food and Drink', 'Restaurants'],
#  ['Shops', 'Sporting Goods'],
#  ['Payment', 'Credit Card'],
#  ['Travel', 'Car Service', 'Ride Share'],
#  ['Transfer', 'Debit'],
#  ['Transfer', 'Deposit'],
#  ['Recreation', 'Gyms and Fitness Centers'],
#  ['Travel', 'Airlines and Aviation Services'],
#  ['Food and Drink', 'Restaurants'],
#  ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#  ['Food and Drink', 'Restaurants'],
#  ['Transfer', 'Credit'],
#  ['Travel', 'Airlines and Aviation Services'],
#  ['Travel', 'Car Service', 'Ride Share']]

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: date, name, amount, category.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# YOUR CODE HERE
transaction_df = pd.DataFrame(columns = ['date','name','amount','category'])
transactions = transactions_response['transactions']
i = 0
for transaction in transactions:
   transaction_df.loc[i] = [transaction["date"],transaction["name"],transaction["amount"],transaction["category"][0]]
   i =i +1
transaction_df.head()
# Out:
#          date                          name  amount        category
# 0  2019-09-28                    Tectra Inc     500  Food and Drink
# 1  2019-09-27     AUTOMATIC PAYMENT - THANK  2078.5         Payment
# 2  2019-09-27                           KFC     500  Food and Drink
# 3  2019-09-27          Madison Bicycle Shop     500           Shops
# 4  2019-09-18  CREDIT CARD 3333 PAYMENT *//      25         Payment

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# YOUR CODE HERE
# transaction_df['category'] = transaction_df['category'].astype(basestring)
transaction_df['date']  = pd.to_datetime(transaction_df['date'])
transaction_df['name'] = transaction_df['name'].astype(str)
transaction_df['amount'] = pd.to_numeric(transaction_df['amount'])
transaction_df['category'] = transaction_df['category'].astype(str)
transaction_df.dtypes
# Out:
# date        datetime64[ns]
# name                object
# amount             float64
# category            object
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
# 1. Determine the previous year's gross income and print the results
# 2. Determine the current monthly income and print the results
# 3. Determine the projected yearly income and print the results

# %%
# YOUR CODE HERE
Income_analysis_py_gross_income = client.Income.get(access_token)
Income_analysis_py_gross_income
pretty_print_response(Income_analysis_py_gross_income)
# Out:
# {
#     "income": {
#         "income_streams": [
#             {
#                 "confidence": 0.99,
#                 "days": 690,
#                 "monthly_income": 500,
#                 "name": "UNITED AIRLINES"
#             }
#         ],
#         "last_year_income": 6000,
#         "last_year_income_before_tax": 7285,
#         "max_number_of_overlapping_income_streams": 1,
#         "number_of_income_streams": 1,
#         "projected_yearly_income": 6085,
#         "projected_yearly_income_before_tax": 7389
#     },
#     "request_id": "IFV8nivTnciQnNP"
# }

# %%
py_gross_income = Income_analysis_py_gross_income ['income']['last_year_income_before_tax']
current_month = Income_analysis_py_gross_income ['income']['income_streams'][0]['monthly_income']
projected_yearly_income = Income_analysis_py_gross_income ['income']['projected_yearly_income_before_tax']

print( "Last Year's Income Before Tax =", py_gross_income)
print( "Current Monthly Income =" ,current_month)
print( "Projected Year's Income Before Tax =", projected_yearly_income)
# Out:
# Last Year's Income Before Tax = 7285
# Current Monthly Income = 500
# Projected Year's Income Before Tax = 7389

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
# 2. Generate a bar chart with the number of transactions for each category
# 3. Calulate the expenses per month
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
transaction_by_category = transaction_df.groupby(["category"])[["amount"]].sum()
transaction_by_category
# Out:
#                   amount
# category
# Food and Drink   3317.19
# Payment          6310.50
# Recreation        235.50
# Shops            1500.00
# Transfer        20537.34
# Travel             35.19

# %%
transaction_by_category.plot.pie(y='amount', figsize=(10, 10))

# %% [markdown]
# ### Calculate the expenses per month

# %%
# YOUR CODE HERE
transaction_df['month'] = pd.DatetimeIndex(transaction_df['date']).month
transaction_per_month = transaction_df.groupby(["month"])[["amount"]].sum()
transaction_per_month.head()
# Out:
#          amount
# month
# 7      10645.24
# 8      10645.24
# 9      10645.24

# %%
transaction_per_month.plot.bar()
